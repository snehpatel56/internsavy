# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Packages
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
import scipy.stats as stats
# %matplotlib inline

# %%
inp0= pd.read_csv("Admission_Predict_Ver1.1.csv")

# %%
inp0
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %%
inp0.shape
# Out:
# (500, 9)

# %%
inp0.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
inp0.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# 495         1              0.87
# 496         1              0.96
# 497         1              0.93
# 498         0              0.73
# 499         0              0.84

# %%
inp0.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
inp0.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
inp0.groupby("University Rating").mean()
# Out:
#                    Serial No.   GRE Score  TOEFL Score       SOP      LOR   \
# University Rating
# 1                  281.558824  304.911765   100.205882  1.941176  2.426471
# 2                  249.555556  309.134921   103.444444  2.682540  2.956349
# 3                  247.574074  315.030864   106.314815  3.308642  3.401235
# 4                  275.809524  323.304762   110.961905  4.000000  3.947619
# 5                  207.753425  327.890411   113.438356  4.479452  4.404110
#
#                        CGPA  Research  Chance of Admit
# University Rating
# 1                  7.798529  0.294118          0.562059
# 2                  8.177778  0.293651          0.626111
# 3                  8.500123  0.537037          0.702901
# 4                  8.936667  0.780952          0.801619
# 5                  9.278082  0.876712          0.888082

# %%
inp0
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 495         496        332          108                  5  4.5   4.0  9.02
# 496         497        337          117                  5  5.0   5.0  9.87
# 497         498        330          120                  5  4.5   5.0  9.56
# 498         499        312          103                  4  4.0   5.0  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# # here chance of admit it more than 82 which is actually third quartile of data

# %%
inp0[inp0["Chance of Admit "]>0.82].groupby("Chance of Admit ").mean()
# Out:
#                   Serial No.   GRE Score  TOEFL Score  University Rating  \
# Chance of Admit
# 0.83              309.000000  326.500000   112.750000           3.750000
# 0.84              255.636364  323.909091   109.636364           3.454545
# 0.85              229.000000  322.000000   111.500000           3.666667
# 0.86              246.900000  325.400000   114.400000           4.200000
# 0.87              273.750000  325.625000   111.125000           4.625000
# 0.88              127.000000  323.000000   110.750000           5.000000
# 0.89              269.000000  328.636364   113.545455           4.363636
# 0.90              186.777778  330.555556   116.111111           4.000000
# 0.91              267.400000  330.500000   115.000000           4.500000
# 0.92              226.888889  328.555556   114.888889           4.777778
# 0.93              268.833333  330.583333   115.916667           4.583333
# 0.94              160.846154  334.230769   116.692308           4.846154
# ...

# %% [markdown]
#  1) Average GPAs of those with higher level of chance to admit is greater than 9 where the data average is 8.57.
#  2) Average LOR, SOP, GRE and TOEFL grades of those with higher level of chance to admit is greater than the data average.
#  3) Research Shows us 75% Research Experience so there may be chances to Reject the Application in the next we take more than 83%

# %%
sns.lineplot(data=inp0, x="Chance of Admit ",y="Research")
plt.figure(figsize=(10,8))
plt.show()

# %%
sns.scatterplot(data=inp0,x="Chance of Admit " , y="University Rating")
# Out:
# <Axes: xlabel='Chance of Admit ', ylabel='University Rating'>

# %%
inp0.hist(bins=20 ,figsize=(10,8))
plt.show()

# %%
inp0.drop(["Serial No."], axis=1, inplace=True)

# %%
var = inp0.columns.tolist()
Y = inp0["Chance of Admit "]
x= [i for i in var if i not in ["Chance of Admit "]]
X= inp0[x]

# %%
X
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 495        332          108                  5  4.5   4.0  9.02         1
# 496        337          117                  5  5.0   5.0  9.87         1
# 497        330          120                  5  4.5   5.0  9.56         1
# 498        312          103                  4  4.0   5.0  8.43         0
# 499        327          113                  4  4.5   4.5  9.04         0
#
# [500 rows x 7 columns]

# %%
Y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test, Y_train ,Y_test = train_test_split(X,Y ,test_size=0.2 , random_state=0)

# %%
from sklearn.preprocessing import MinMaxScaler
new = MinMaxScaler()
X_train[X_train.columns] = new.fit_transform(X_train[X_train.columns])
X_test[X_test.columns] = new.fit_transform(X_test[X_test.columns])

# %%
inp0.rename(columns={'Chance of Admit  ': "chance"},inplace=True)

# %%
cy_train=[1 if chance > 0.82 else 0 for chance in Y_train]
cy_train=np.array(cy_train) 

cy_test=[1 if chance > 0.82 else 0 for chance in Y_test]
cy_test=np.array(cy_test)

# %%
# Fitting Logistic Regression model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, cy_train)


# Printing accuracy score & confusion matrix
from sklearn.metrics import accuracy_score
print('Logistic Regression accuracy: {:.3f}'.format(accuracy_score(cy_test, lr.predict(X_test))))
print('--------------------------------------')
from sklearn.metrics import classification_report
print(classification_report(cy_test, lr.predict(X_test)))
# Out:
# Logistic Regression accuracy: 0.960
# --------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        80
#            1       0.90      0.90      0.90        20
#
#     accuracy                           0.96       100
#    macro avg       0.94      0.94      0.94       100
# weighted avg       0.96      0.96      0.96       100

# %%
from sklearn.metrics import confusion_matrix

cy = lr.predict(X_test)  # Assuming lr is your logistic regression model
lr_confm = confusion_matrix(cy_test, cy)  # Corrected the order of arguments
sns.heatmap(lr_confm, annot=True, fmt='.2f', xticklabels=["Admitted", "Rejected"], yticklabels=["Admitted", "Rejected"])
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.title('Logistic Regression')
plt.show()

# %%
# Fitting random forest model
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, cy_train)


# Printing accuracy score & confusion matrix
from sklearn.metrics import accuracy_score
print('Random Forest accuracy: {:.3f}'.format(accuracy_score(cy_test, rf.predict(X_test))))
print('--------------------------------------')
from sklearn.metrics import classification_report
print(classification_report(cy_test, rf.predict(X_test)))
# Out:
# Random Forest accuracy: 0.950
# --------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        80
#            1       0.94      0.80      0.86        20
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.89      0.92       100
# weighted avg       0.95      0.95      0.95       100

# %%
from sklearn.metrics import confusion_matrix

cy = rf.predict(X_test)  # Assuming lr is your logistic regression model
rf_confm = confusion_matrix(cy_test, cy)  # Corrected the order of arguments
sns.heatmap(rf_confm, annot=True, fmt='.2f', xticklabels=["Admitted", "Rejected"], yticklabels=["Admitted", "Rejected"])
plt.ylabel('Actual Class')
plt.xlabel('Predicted Class')
plt.title('Logistic Regression')
plt.show()

# %%
imp = pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=True)
print(imp)
# Out:
# Research             0.017846
# SOP                  0.053799
# LOR                  0.056761
# University Rating    0.125124
# GRE Score            0.181213
# TOEFL Score          0.198390
# CGPA                 0.366868
# dtype: float64
